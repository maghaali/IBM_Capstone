# %% [markdown]
# # Final project of the __*IBM Data Science Professional Certificate*__

# %% [markdown]
# ##### __Title__: *City guide of Vancouver, BC, Canada*
# ##### __Description__: *The best hotels, restaurants and urban places in "Vancouver, BC, Canada" that are close to the public transportation system, such as buses or subways, to help tourists have a better and cheaper experience.*
# ##### __Steps__:
# * ##### Sign up for Foursquare developer account, to be able to use Foursquare's API
# * ##### Retrieve information of urban places, hotels, restaurants, bus stops and metro stations with sequentially names as urban_jo, hotel_jo, rest_jo, bus_jo, metro_jo (Note that they are json files)
# * ##### Based on their id value retrieve rating of places and filter to have best ones (over 7)
# * ##### Cleansing data
# * ##### Retrieve Latitude, Longitude, user rate, name, type of each title and put them into pandas DataFrame with sequentially names as urban_df, hotel_df, rest_df, bus_df, metro_df
# * ##### Last step is visualizing our data on map with Folium Library
#
# ##### __Question__: *How it can help tourist?*
# * ##### This report will create an object of best hotels, restaurants, urban places and available metro and bus stations on map with exact location so tourist can make a good plan for his/her travel to Vancouver which plac he/she want to stay at and diversity of hugh rank urban places to go and visit them
#
# ##### __Reporter github__:  *https://github.com/spacelover92*

# %% [markdown]
# ### 1. Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

# %% [markdown]
# #### In this part of notebook we're going to create a dataframe of all high rank (over 7) hotels of "Vancouver, BC, Canada"
# #### Final result will save into "hotel_df.csv" file

# %% [markdown]
# ### 2. Set credentials from Foursquare developer website

# %%
CLIENT_ID = ''   # put your client id
CLIENT_SECRET = ''  # put your client isecretd
VERSION = '20201025'  # set version #for example 20201025 means October 25, 2020
LIMIT = 50 # Number of requests

# %% [markdown]
# #### Note: Since we are going to explore all hotels of Vancouver so I used *near* but if you want to find neighborhoods of specific location instead of *near* you must use *ll* which stands for latitude and longtitude of that place
#
# #### Note: search_quesry is used which specific keywork in this case I used *Hotel* to find all hotels

# %%
NEAR = 'Vancouver,BC,Canada'
search_query = 'Hotel'

# %% [markdown]
# #### 3. Define the corresponding URL
#
# ##### Now, it's time to create our *url* based on documentation of Foursquare API

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&near={}&v={}&query={}&limit={}'.format(CLIENT_ID, 
                                                                                                                         CLIENT_SECRET, 
                                                                                                                         NEAR, 
                                                                                                                         VERSION, 
                                                                                                                         search_query,  
                                                                                                                         LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=M0NI1LWGR33KCW3MNT1E3MTJIV1RT0W2VVCLFFFRNTUNKEYL&client_secret=51ULMM5KM3ABRORQ45Z545UWQFJLRCGSPXUTABRIVDELSPHH&near=Vancouver,BC,Canada&v=20201025&query=Hotel&limit=50'

# %% [markdown]
# #### 4. Send the GET Request and examine the hotel_jo
#
# ##### With line below we are going to retrieve our data and save it as a json file in hotel_jo

# %%
hotel_jo = requests.get(url).json()
hotel_jo
# Out:
# {'meta': {'code': 200, 'requestId': '5f94f9719d7cfa6c1bb4e777'},
#  'response': {'venues': [{'id': '4aa738def964a520594c20e3',
#     'name': 'Opus Hotel',
#     'location': {'address': '322 Davie St.',
#      'crossStreet': 'at Hamilton St.',
#      'lat': 49.274654423320435,
#      'lng': -123.12233189716328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.274654423320435,
#        'lng': -123.12233189716328}],
#      'postalCode': 'V6B 5Z6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['322 Davie St. (at Hamilton St.)',
#       'Vancouver BC V6B 5Z6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bd09a421f89ce723fb967ea',
#     'name': 'The Sylvia Hotel',
#     'location': {'address': '1154 Gilford St',
#      'lat': 49.288784,
#      'lng': -123.142615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.288784,
#        'lng': -123.142615}],
#      'postalCode': 'V6G 2P6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1154 Gilford St',
#       'Vancouver BC V6G 2P6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b0ae864f964a520d72923e3',
#     'name': 'Executive Hotel Vintage Park',
#     'location': {'address': '1379 Howe St.',
#      'crossStreet': 'at Pacific St.',
#      'lat': 49.27591745566755,
#      'lng': -123.1303168826212,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.27591745566755,
#        'lng': -123.1303168826212}],
#      'postalCode': 'V6Z 2R5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1379 Howe St. (at Pacific St.)',
#       'Vancouver BC V6Z 2R5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ee7d0330aaf40cac3cd958b',
#     'name': 'Executive Plaza Hotel',
#     'location': {'lat': 49.26336582709051,
#      'lng': -123.13461542129517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.26336582709051,
#        'lng': -123.13461542129517}],
#      'postalCode': 'V6H 1H2',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['Vancouver BC V6H 1H2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ba56584f964a520150339e3',
#     'name': 'Best Western Plus Uptown Hotel',
#     'location': {'address': '205 Kingsway',
#      'lat': 49.26176997209943,
#      'lng': -123.09808201270062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.26176997209943,
#        'lng': -123.09808201270062}],
#      'postalCode': 'V5T 3J5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['205 Kingsway', 'Vancouver BC V5T 3J5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4d188bfcbb64224b4108c865',
#     'name': 'City Centre Motor Hotel',
#     'location': {'address': '2111 Main St.',
#      'crossStreet': 'at 6th Ave.',
#      'lat': 49.265615514386646,
#      'lng': -123.10127506393786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.265615514386646,
#        'lng': -123.10127506393786}],
#      'postalCode': 'V5T 3C6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['2111 Main St. (at 6th Ave.)',
#       'Vancouver BC V5T 3C6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bd5c5589649ce7223a6511d',
#     'name': 'Holiday Inn Hotel & Suites Vancouver Downtown',
#     'location': {'address': '1110 Howe Street',
#      'lat': 49.2785379,
#      'lng': -123.1256485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2785379,
#        'lng': -123.1256485}],
#      'postalCode': 'V6Z 1R2',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1110 Howe Street',
#       'Vancouver BC V6Z 1R2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4af0f4e4f964a5204ae021e3',
#     'name': 'The Fairmont Hotel Vancouver',
#     'location': {'address': '900 West Georgia Street',
#      'crossStreet': 'btwn Burrard & Hornby',
#      'lat': 49.283805486323196,
#      'lng': -123.120944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.283805486323196,
#        'lng': -123.120944}],
#      'postalCode': 'V6C 2W6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['900 West Georgia Street (btwn Burrard & Hornby)',
#       'Vancouver BC V6C 2W6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4d5ec8ce29ef236ae0cb9059',
#     'name': 'Rosewood Hotel Georgia',
#     'location': {'address': '801 W Georgia St',
#      'crossStreet': 'at Howe St',
#      'lat': 49.28342914255638,
#      'lng': -123.1189107326352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28342914255638,
#        'lng': -123.1189107326352}],
#      'postalCode': 'V6C 1P7',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['801 W Georgia St (at Howe St)',
#       'Vancouver BC V6C 1P7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '37012938'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab4f20f964a520615920e3',
#     'name': 'Century Plaza Hotel & Spa',
#     'location': {'address': '1015 Burrard St',
#      'crossStreet': '@ Nelson St',
#      'lat': 49.28065690166794,
#      'lng': -123.12684048007954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28065690166794,
#        'lng': -123.12684048007954}],
#      'postalCode': 'V6Z 1Y5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1015 Burrard St (@ Nelson St)',
#       'Vancouver BC V6Z 1Y5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b9b2307f964a5206df535e3',
#     'name': 'Best Western Plus Chateau Granville Hotel & Suites & Conference Ctr.',
#     'location': {'address': '1100 Granville St',
#      'crossStreet': 'at Helmcken St.',
#      'lat': 49.277823,
#      'lng': -123.12463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.277823,
#        'lng': -123.12463}],
#      'postalCode': 'V6Z 2B6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1100 Granville St (at Helmcken St.)',
#       'Vancouver BC V6Z 2B6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '36728873'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aa74575f964a5208f4c20e3',
#     'name': 'Sutton Place Hotel Vancouver',
#     'location': {'address': '845 Burrard Street',
#      'crossStreet': 'btwn Smithe St & Robson St',
#      'lat': 49.28264004904225,
#      'lng': -123.12387529266849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28264004904225,
#        'lng': -123.12387529266849}],
#      'postalCode': 'V6Z 2K6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['845 Burrard Street (btwn Smithe St & Robson St)',
#       'Vancouver BC V6Z 2K6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '584836110'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4a8e147cf964a520fc1120e3',
#     'name': 'Sandman Hotel Vancouver City Centre',
#     'location': {'address': '180 W. Georgia Street',
#      'crossStreet': 'Cambie St',
#      'lat': 49.27923800244187,
#      'lng': -123.112841119878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.27923800244187,
#        'lng': -123.112841119878}],
#      'postalCode': 'V6B 4P4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['180 W. Georgia Street (Cambie St)',
#       'Vancouver BC V6B 4P4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b806d95f964a5206e7130e3',
#     'name': 'Riviera on Robson Suites Hotel',
#     'location': {'address': '1431 Robson St',
#      'lat': 49.28835687769901,
#      'lng': -123.13020061543632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28835687769901,
#        'lng': -123.13020061543632}],
#      'postalCode': 'V6G 1C3',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1431 Robson St', 'Vancouver BC V6G 1C3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab548ef964a520725920e3',
#     'name': 'Hotel LeSoleil',
#     'location': {'address': '567 Hornby Street',
#      'crossStreet': 'btn W Pender and Dunsmuir',
#      'lat': 49.285332091018624,
#      'lng': -123.11811069694004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.285332091018624,
#        'lng': -123.11811069694004}],
#      'postalCode': 'V6C 2E8',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['567 Hornby Street (btn W Pender and Dunsmuir)',
#       'Vancouver BC V6C 2E8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab4ce8f964a5205a5920e3',
#     'name': 'Vancouver Marriott Pinnacle Downtown Hotel',
#     'location': {'address': '1128 West Hastings Street',
#      'lat': 49.28778960562971,
#      'lng': -123.12036466521064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28778960562971,
#        'lng': -123.12036466521064}],
#      'postalCode': 'V6E 4R5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1128 West Hastings Street',
#       'Vancouver BC V6E 4R5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '129932557'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4abe5a61f964a520ec8c20e3',
#     'name': 'Four Seasons Hotel Vancouver',
#     'location': {'address': '791 West Georgia Street',
#      'lat': 49.283210306080946,
#      'lng': -123.1184071919454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.283210306080946,
#        'lng': -123.1184071919454}],
#      'postalCode': 'V6C 2T4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['791 West Georgia Street',
#       'Vancouver BC V6C 2T4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4acd3910f964a5207dcb20e3',
#     'name': 'Shangri-La Hotel',
#     'location': {'address': '1128 West Georgia St.',
#      'crossStreet': 'Thurlow',
#      'lat': 49.28593423238485,
#      'lng': -123.12408050709615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28593423238485,
#        'lng': -123.12408050709615}],
#      'postalCode': 'V6E 0A8',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1128 West Georgia St. (Thurlow)',
#       'Vancouver BC V6E 0A8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b7cf5e1f964a52066aa2fe3',
#     'name': 'Hotel at the Waldorf',
#     'location': {'address': '1489 E Hastings St',
#      'crossStreet': 'btwn Commercial & Clark',
#      'lat': 49.28145565110179,
#      'lng': -123.07463277709543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28145565110179,
#        'lng': -123.07463277709543}],
#      'postalCode': 'V5L 1S4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1489 E Hastings St (btwn Commercial & Clark)',
#       'Vancouver BC V5L 1S4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '86415534'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b99e544f964a5201f9635e3',
#     'name': 'Georgian Court Hotel',
#     'location': {'address': '773 Beatty St',
#      'crossStreet': 'btw Robson St. and Georgia St.',
#      'lat': 49.278236627377424,
#      'lng': -123.11348480489346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.278236627377424,
#        'lng': -123.11348480489346}],
#      'postalCode': 'V6B 2M4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['773 Beatty St (btw Robson St. and Georgia St.)',
#       'Vancouver BC V6B 2M4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '47719517'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab560af964a520785920e3',
#     'name': 'Metropolitan Hotel Vancouver',
#     'location': {'address': '645 Howe Street',
#      'lat': 49.2841801,
#      'lng': -123.1184303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2841801,
#        'lng': -123.1184303}],
#      'postalCode': 'V6C 2Y9',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['645 Howe Street',
#       'Vancouver BC V6C 2Y9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4af2380af964a520aae621e3',
#     'name': 'YWCA Hotel/Residence',
#     'location': {'address': '733 Beatty St.',
#      'crossStreet': 'Off Robson St.',
#      'lat': 49.27841416220364,
#      'lng': -123.11276964174914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.27841416220364,
#        'lng': -123.11276964174914}],
#      'postalCode': 'V6B 4P4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['733 Beatty St. (Off Robson St.)',
#       'Vancouver BC V6B 4P4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '45901530'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ba7ce4ef964a520fbb439e3',
#     'name': 'Vancouver Airport Marriott Hotel',
#     'location': {'address': '7571 Westminster Highway',
#      'lat': 49.17056189669989,
#      'lng': -123.14062854509757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.17056189669989,
#        'lng': -123.14062854509757}],
#      'postalCode': 'V6X 1A3',
#      'cc': 'CA',
#      'city': 'Richmond',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['7571 Westminster Highway',
#       'Richmond BC V6X 1A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '129932558'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '51c2302d498e6c1fcae32130',
#     'name': 'Trump International Hotel & Tower® Vancouver',
#     'location': {'address': '1161 W Georgia St',
#      'crossStreet': 'Bute Street',
#      'lat': 49.2865695,
#      'lng': -123.1244027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2865695,
#        'lng': -123.1244027}],
#      'postalCode': 'V6E 0C6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1161 W Georgia St (Bute Street)',
#       'Vancouver BC V6E 0C6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ad5f692f964a520350421e3',
#     'name': 'Coast Coal Harbour Vancouver Hotel by APA',
#     'location': {'address': '1180 West Hastings',
#      'crossStreet': 'Hastings & Bute',
#      'lat': 49.288401,
#      'lng': -123.122343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.288401,
#        'lng': -123.122343}],
#      'postalCode': 'V6E 4R5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1180 West Hastings (Hastings & Bute)',
#       'Vancouver BC V6E 4R5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '512550599'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ca0679019e4236abef06089',
#     'name': 'Greenbrier Hotel',
#     'location': {'address': '1393 Robson Street',
#      'lat': 49.287912665171234,
#      'lng': -123.12960045288793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.287912665171234,
#        'lng': -123.12960045288793}],
#      'postalCode': 'V6E 1C3',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1393 Robson Street',
#       'Vancouver BC V6E 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '85501752'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '580cdb3dd67cd129a2200731',
#     'name': 'Health Club at Sheraton Vancouver Wall Center Hotel',
#     'location': {'lat': 49.280777,
#      'lng': -123.125984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.280777,
#        'lng': -123.125984}],
#      'postalCode': 'V6Z 2R9',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['Vancouver BC V6Z 2R9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4dc5f785887717c880324075',
#     'name': 'St. Clair Hotel - Hostel',
#     'location': {'address': '577 Richards St.',
#      'crossStreet': 'btwn W Hastings & Dunsmuir',
#      'lat': 49.2827361940718,
#      'lng': -123.11442132599076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2827361940718,
#        'lng': -123.11442132599076}],
#      'postalCode': 'V6B 2Z5',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['577 Richards St. (btwn W Hastings & Dunsmuir)',
#       'Vancouver BC V6B 2Z5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aeca6c6f964a520eec921e3',
#     'name': 'The Kingston Hotel Bed and Breakfast',
#     'location': {'address': '757 Richards Street',
#      'crossStreet': 'Between Robson + Georgia',
#      'lat': 49.28072220584647,
#      'lng': -123.11718508887402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28072220584647,
#        'lng': -123.11718508887402}],
#      'postalCode': 'V6B 3A6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['757 Richards Street (Between Robson + Georgia)',
#       'Vancouver BC V6B 3A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bd09a3f1f89ce723bb967ea',
#     'name': 'Victorian Hotel Vancouver',
#     'location': {'address': '514 Homer St Vancouver BC Canada',
#      'crossStreet': 'Pender',
#      'lat': 49.28251724902659,
#      'lng': -123.11214421109624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28251724902659,
#        'lng': -123.11214421109624}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['514 Homer St Vancouver BC Canada (Pender)',
#       'Vancouver BC',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4f66afede4b0bf1013f09271',
#     'name': '1606 @ Century Plaza Hotel & Spa',
#     'location': {'address': '1015 Burrard St.',
#      'crossStreet': 'Nelson St.',
#      'lat': 49.2810869018745,
#      'lng': -123.12706678675399,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2810869018745,
#        'lng': -123.12706678675399}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1015 Burrard St. (Nelson St.)',
#       'Vancouver BC',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '533caeaa11d29c2479d8b64e',
#     'name': 'Burrard Hotel',
#     'location': {'lat': 49.27988051110661,
#      'lng': -123.12732844239103,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.27988051110661,
#        'lng': -123.12732844239103}],
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['Vancouver BC', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4b7f88cbf964a520613330e3',
#     'name': 'West Hotel Bar',
#     'location': {'address': '488 Carrall St',
#      'lat': 49.280578314366295,
#      'lng': -123.10430193695167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.280578314366295,
#        'lng': -123.10430193695167}],
#      'postalCode': 'V6B 2J7',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['488 Carrall St', 'Vancouver BC V6B 2J7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'shortName': 'Dive Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bf0811f6f8aa593b1fcc13c',
#     'name': 'Sandman Hotel Vancouver Airport',
#     'location': {'address': '3233 St. Edwards Drive',
#      'lat': 49.18731231982369,
#      'lng': -123.10991670043694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.18731231982369,
#        'lng': -123.10991670043694}],
#      'postalCode': 'V6X 3K4',
#      'cc': 'CA',
#      'city': 'Richmond',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['3233 St. Edwards Drive',
#       'Richmond BC V6X 3K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4d79718bb359f04d1f77c714',
#     'name': 'Shangri-La Hotel Gift Shop',
#     'location': {'address': '1128 W Georgia St',
#      'crossStreet': 'at Thurlow St',
#      'lat': 49.285843,
#      'lng': -123.123939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.285843,
#        'lng': -123.123939}],
#      'postalCode': 'V6E 0A8',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1128 W Georgia St (at Thurlow St)',
#       'Vancouver BC V6E 0A8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '50ef23afe4b04e0d11da9edd',
#     'name': 'Afternoon Tea At The Fairmont Hotel',
#     'location': {'address': '900 West Georgia Street',
#      'lat': 49.28386047597524,
#      'lng': -123.1209028770766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.28386047597524,
#        'lng': -123.1209028770766}],
#      'postalCode': 'V6C 2W6',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['900 West Georgia Street',
#       'Vancouver BC V6C 2W6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aa8720df964a520545120e3',
#     'name': 'Plaza 500 Hotel',
#     'location': {'address': '500 W. 12th Ave',
#      'crossStreet': 'Cambie',
#      'lat': 49.260282,
#      'lng': -123.115433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.260282,
#        'lng': -123.115433}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['500 W. 12th Ave (Cambie)',
#       'Vancouver BC',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bd744ae304fce722b4a33ab',
#     'name': 'Radisson Hotel Vancouver Airport',
#     'location': {'address': '8181 Cambie Road',
#      'lat': 49.185186990585585,
#      'lng': -123.13548445701593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.185186990585585,
#        'lng': -123.13548445701593}],
#      'postalCode': 'V6X 3X9',
#      'cc': 'CA',
#      'city': 'Richmond',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['8181 Cambie Road',
#       'Richmond BC V6X 3X9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '63943521'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4af32fb0f964a5208aeb21e3',
#     'name': 'Executive Airport Plaza Hotel',
#     'location': {'address': '7311 Westminster Hwy.',
#      'lat': 49.17058434191942,
#      'lng': -123.14589652536898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.17058434191942,
#        'lng': -123.14589652536898}],
#      'postalCode': 'V6X 1A3',
#      'cc': 'CA',
#      'city': 'Richmond',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['7311 Westminster Hwy.',
#       'Richmond BC V6X 1A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '5d0475892632ec002c3700fd',
#     'name': 'Hotel Belmont',
#     'location': {'lat': 49.2791,
#      'lng': -123.123085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2791,
#        'lng': -123.123085}],
#      'postalCode': 'V6B 6K4',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['Vancouver BC V6B 6K4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4ee524c5f790897ed1175fb5',
#     'name': 'Hotel Nathoo',
#     'location': {'lat': 49.271329015509416,
#      'lng': -123.1239860132618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.271329015509416,
#        'lng': -123.1239860132618}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['Vancouver BC', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '536df916498e122752bc08a3',
#     'name': 'Hotel Blu',
#     'location': {'address': '177 Robson Street',
#      'lat': 49.278342669044825,
#      'lng': -123.11444104804278,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.278342669044825,
#        'lng': -123.11444104804278}],
#      'postalCode': 'V6B 0N3',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['177 Robson Street',
#       'Vancouver BC V6B 0N3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bce3b55cc8cd13af40bc4cf',
#     'name': 'Pinnacle Hotel At The Pier',
#     'location': {'address': '138 Victory Ship Way',
#      'crossStreet': 'Lonsdale and Esplanade',
#      'lat': 49.310460983581685,
#      'lng': -123.07896474929457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.310460983581685,
#        'lng': -123.07896474929457}],
#      'postalCode': 'V7L 0B1',
#      'cc': 'CA',
#      'city': 'North Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['138 Victory Ship Way (Lonsdale and Esplanade)',
#       'North Vancouver BC V7L 0B1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90490185'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab4eb7f964a520605920e3',
#     'name': 'The Buchan Hotel',
#     'location': {'address': '1906 Haro Street',
#      'crossStreet': 'btn Chilco and Denman',
#      'lat': 49.2917255624254,
#      'lng': -123.1383758735297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2917255624254,
#        'lng': -123.1383758735297}],
#      'postalCode': 'V6G 1H7',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1906 Haro Street (btn Chilco and Denman)',
#       'Vancouver BC V6G 1H7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4c69803e8d22c928fb66b745',
#     'name': 'The Lobby Restaurant at the Pinnacle Hotel',
#     'location': {'address': '138 Victory Ship Way',
#      'crossStreet': 'Victory Ship Way & Lonsdale',
#      'lat': 49.310415900015975,
#      'lng': -123.0791320677291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.310415900015975,
#        'lng': -123.0791320677291}],
#      'postalCode': 'V7L 0B1',
#      'cc': 'CA',
#      'city': 'North Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['138 Victory Ship Way (Victory Ship Way & Lonsdale)',
#       'North Vancouver BC V7L 0B1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90488288'},
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4aab5297f964a5206c5920e3',
#     'name': 'Granville Island Hotel',
#     'location': {'address': '1253 Johnston St',
#      'crossStreet': 'by Cartwright St',
#      'lat': 49.2697671,
#      'lng': -123.1321867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.2697671,
#        'lng': -123.1321867}],
#      'postalCode': 'V6H 3R9',
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1253 Johnston St (by Cartwright St)',
#       'Vancouver BC V6H 3R9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bae5cd1f964a52007a83be3',
#     'name': 'Best Western Plus Burnaby Hotel And Conference Centre',
#     'location': {'address': '5411 Kingsway',
#      'lat': 49.224288,
#      'lng': -122.9859723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.224288,
#        'lng': -122.9859723}],
#      'postalCode': 'V5H 2G1',
#      'cc': 'CA',
#      'city': 'Burnaby',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['5411 Kingsway', 'Burnaby BC V5H 2G1', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4e3b97b78877b00cfc2e5102',
#     'name': 'Hotel Ambassador',
#     'location': {'address': '1212 Granville Street',
#      'crossStreet': 'Davies',
#      'lat': 49.27692588502403,
#      'lng': -123.12635719243089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.27692588502403,
#        'lng': -123.12635719243089}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['1212 Granville Street (Davies)',
#       'Vancouver BC',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4bd462c49854d13a0f74ff4d',
#     'name': 'Travelodge Hotel by Wyndham Vancouver Airport',
#     'location': {'address': '3071 St. Edwards Dr',
#      'crossStreet': 'Bridgeport Rd',
#      'lat': 49.1914526019506,
#      'lng': -123.113041030517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.1914526019506,
#        'lng': -123.113041030517}],
#      'postalCode': 'V6X 3K4',
#      'cc': 'CA',
#      'city': 'Richmond',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['3071 St. Edwards Dr (Bridgeport Rd)',
#       'Richmond BC V6X 3K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False},
#    {'id': '4f4b5308121dad8c5532ac16',
#     'name': 'Hodgson Hotel',
#     'location': {'address': '700 east 28th Avenue',
#      'lat': 49.245719003247686,
#      'lng': -123.09058427810669,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.245719003247686,
#        'lng': -123.09058427810669}],
#      'cc': 'CA',
#      'city': 'Vancouver',
#      'state': 'BC',
#      'country': 'Canada',
#      'formattedAddress': ['700 east 28th Avenue', 'Vancouver BC', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603598705',
#     'hasPerk': False}],
#   'geocode': {'what': '',
#    'where': 'vancouver bc canada',
#    'feature': {'cc': 'CA',
#     'name': 'Vancouver',
#     'displayName': 'Vancouver, BC, Canada',
#     'matchedName': 'Vancouver, BC, Canada',
#     'highlightedName': '<b>Vancouver</b>, <b>BC</b>, <b>Canada</b>',
#     'woeType': 7,
#     'slug': 'vancouver-british-columbia-canada',
#     'id': 'geonameid:6173331',
#     'longId': '72057594044101267',
#     'geometry': {'center': {'lat': 49.24966, 'lng': -123.11934},
#      'bounds': {'ne': {'lat': 49.31439002686205, 'lng': -123.02296611995233},
#       'sw': {'lat': 49.19840801038309, 'lng': -123.22524087683938}}}},
#    'parents': []}}}

# %% [markdown]
# #### 4. Get relevant part of JSON and transform it into a _pandas_ dataframe
#
# ##### With examining json above we are going to retrieve relevant part of json and create Pandas DataFrame based on them

# %%
# assign relevant part of JSON to venues
venues = hotel_jo['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                            name  \
# 0  4aa738def964a520594c20e3                      Opus Hotel
# 1  4bd09a421f89ce723fb967ea                The Sylvia Hotel
# 2  4b0ae864f964a520d72923e3    Executive Hotel Vintage Park
# 3  4ee7d0330aaf40cac3cd958b           Executive Plaza Hotel
# 4  4ba56584f964a520150339e3  Best Western Plus Uptown Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0    322 Davie St.      at Hamilton St.     49.274654   -123.122332
# 1  1154 Gilford St                  NaN     49.288784   -123.142615
# 2    1379 Howe St.       at Pacific St.     49.275917   -123.130317
# 3              NaN                  NaN     49.263366   -123.134615
# 4     205 Kingsway                  NaN     49.261770   -123.098082
#
#                              location.labeledLatLngs location.postalCode  \
# 0  [{'label': 'display', 'lat': 49.27465442332043...             V6B 5Z6
# 1  [{'label': 'display', 'lat': 49.288784, 'lng':...             V6G 2P6
# 2  [{'label': 'display', 'lat': 49.27591745566755...             V6Z 2R5
# 3  [{'label': 'display', 'lat': 49.26336582709051...             V6H 1H2
# 4  [{'label': 'display', 'lat': 49.26176997209943...             V5T 3J5
#
#   location.cc location.city location.state location.country  \
# 0          CA     Vancouver             BC           Canada
# 1          CA     Vancouver             BC           Canada
# 2          CA     Vancouver             BC           Canada
# 3          CA     Vancouver             BC           Canada
# 4          CA     Vancouver             BC           Canada
#
#                            location.formattedAddress venuePage.id  \
# 0  [322 Davie St. (at Hamilton St.), Vancouver BC...          NaN
# 1    [1154 Gilford St, Vancouver BC V6G 2P6, Canada]          NaN
# 2  [1379 Howe St. (at Pacific St.), Vancouver BC ...          NaN
# 3                     [Vancouver BC V6H 1H2, Canada]          NaN
# 4       [205 Kingsway, Vancouver BC V5T 3J5, Canada]          NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# #### 5. Iteration through ID of hotels to find ratings and store them in new data frame
#
# ##### Whith this part of code we are creating new url for each id in dataframe above to find and retrieve rating of each hotel and create a list of IDs and ratings and store them in list_

# %%
list_ = []
for id in dataframe['id']:
    venue_id = id
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        list_.append([id,result['response']['venue']['rating']])
    except:
        continue # If hotel doesn't have rating we gently skip that hotel

# %% [markdown]
# #### Convert rating list to Pandas DataFrame
#
# ###### Now, we're going to conver our list to Pandas DataFrame

# %%
list_df = pd.DataFrame(list_)
list_df
# Out:
#                            0    1
# 0   4aa738def964a520594c20e3  8.4
# 1   4bd09a421f89ce723fb967ea  7.5
# 2   4b0ae864f964a520d72923e3  5.3
# 3   4ba56584f964a520150339e3  6.1
# 4   4d188bfcbb64224b4108c865  5.4
# 5   4bd5c5589649ce7223a6511d  6.6
# 6   4af0f4e4f964a5204ae021e3  8.5
# 7   4d5ec8ce29ef236ae0cb9059  9.3
# 8   4aab4f20f964a520615920e3  6.0
# 9   4b9b2307f964a5206df535e3  7.9
# 10  4aa74575f964a5208f4c20e3  8.6
# 11  4a8e147cf964a520fc1120e3  5.4
# 12  4b806d95f964a5206e7130e3  5.6
# 13  4aab548ef964a520725920e3  8.3
# 14  4aab4ce8f964a5205a5920e3  7.5
# 15  4abe5a61f964a520ec8c20e3  8.0
# 16  4acd3910f964a5207dcb20e3  8.6
# 17  4b7cf5e1f964a52066aa2fe3  6.1
# 18  4b99e544f964a5201f9635e3  8.2
# 19  4aab560af964a520785920e3  7.1
# 20  4af2380af964a520aae621e3  7.3
# 21  4ba7ce4ef964a520fbb439e3  5.6
# 22  51c2302d498e6c1fcae32130  6.0
# 23  4ad5f692f964a520350421e3  8.3
# 24  4ca0679019e4236abef06089  5.0
# 25  4dc5f785887717c880324075  6.2
# 26  4aeca6c6f964a520eec921e3  6.2
# 27  4bd09a3f1f89ce723bb967ea  7.8
# 28  4bf0811f6f8aa593b1fcc13c  5.7
# 29  4bd744ae304fce722b4a33ab  5.7
# 30  4af32fb0f964a5208aeb21e3  5.8

# %% [markdown]
# #### set column names
# ##### As we see we need to change column names

# %%
list_df.rename(columns={0:'id',1:'rating'}, inplace=True)
list_df
# Out:
#                           id  rating
# 0   4aa738def964a520594c20e3     8.4
# 1   4bd09a421f89ce723fb967ea     7.5
# 2   4b0ae864f964a520d72923e3     5.3
# 3   4ba56584f964a520150339e3     6.1
# 4   4d188bfcbb64224b4108c865     5.4
# 5   4bd5c5589649ce7223a6511d     6.6
# 6   4af0f4e4f964a5204ae021e3     8.5
# 7   4d5ec8ce29ef236ae0cb9059     9.3
# 8   4aab4f20f964a520615920e3     6.0
# 9   4b9b2307f964a5206df535e3     7.9
# 10  4aa74575f964a5208f4c20e3     8.6
# 11  4a8e147cf964a520fc1120e3     5.4
# 12  4b806d95f964a5206e7130e3     5.6
# 13  4aab548ef964a520725920e3     8.3
# 14  4aab4ce8f964a5205a5920e3     7.5
# 15  4abe5a61f964a520ec8c20e3     8.0
# 16  4acd3910f964a5207dcb20e3     8.6
# 17  4b7cf5e1f964a52066aa2fe3     6.1
# 18  4b99e544f964a5201f9635e3     8.2
# 19  4aab560af964a520785920e3     7.1
# 20  4af2380af964a520aae621e3     7.3
# 21  4ba7ce4ef964a520fbb439e3     5.6
# 22  51c2302d498e6c1fcae32130     6.0
# 23  4ad5f692f964a520350421e3     8.3
# 24  4ca0679019e4236abef06089     5.0
# 25  4dc5f785887717c880324075     6.2
# 26  4aeca6c6f964a520eec921e3     6.2
# 27  4bd09a3f1f89ce723bb967ea     7.8
# 28  4bf0811f6f8aa593b1fcc13c     5.7
# 29  4bd744ae304fce722b4a33ab     5.7
# 30  4af32fb0f964a5208aeb21e3     5.8

# %% [markdown]
# ### 6. Now its time to have a one complete data frame with all of data which we need so,

# %% [markdown]
# ##### Left join two dataframes based on id column
# ##### Why left join? then we just keep hotels with rating

# %%
ljoin_df = pd.merge(list_df, dataframe,
                       how="left", on=["id"])

# %%
ljoin_df.shape
# Out:
# (31, 19)

# %% [markdown]
# #### It's time to filter our data and make it more efficient

# %% [markdown]
# ##### So we have list of 31 hotel in Vancouver city
# ###### It's time to order them by rating and choose hotels with overal rank of 7 or greater

# %%
ljoin_df.sort_values(by='rating', ascending=False, inplace=True)
ljoin_df = ljoin_df[ljoin_df['rating']>=7]

# %%
ljoin_df.reset_index(inplace=True)

# %%
ljoin_df.shape
# Out:
# (15, 20)

# %%
ljoin_df
# Out:
#     index                        id  rating  \
# 0       7  4d5ec8ce29ef236ae0cb9059     9.3
# 1      10  4aa74575f964a5208f4c20e3     8.6
# 2      16  4acd3910f964a5207dcb20e3     8.6
# 3       6  4af0f4e4f964a5204ae021e3     8.5
# 4       0  4aa738def964a520594c20e3     8.4
# 5      23  4ad5f692f964a520350421e3     8.3
# 6      13  4aab548ef964a520725920e3     8.3
# 7      18  4b99e544f964a5201f9635e3     8.2
# 8      15  4abe5a61f964a520ec8c20e3     8.0
# 9       9  4b9b2307f964a5206df535e3     7.9
# 10     27  4bd09a3f1f89ce723bb967ea     7.8
# 11     14  4aab4ce8f964a5205a5920e3     7.5
# 12      1  4bd09a421f89ce723fb967ea     7.5
# 13     20  4af2380af964a520aae621e3     7.3
# 14     19  4aab560af964a520785920e3     7.1
#
#                                                  name  \
# 0                              Rosewood Hotel Georgia
# 1                        Sutton Place Hotel Vancouver
# 2                                    Shangri-La Hotel
# 3                        The Fairmont Hotel Vancouver
# 4                                          Opus Hotel
# 5           Coast Coal Harbour Vancouver Hotel by APA
# 6                                      Hotel LeSoleil
# 7                                Georgian Court Hotel
# 8                        Four Seasons Hotel Vancouver
# 9   Best Western Plus Chateau Granville Hotel & Su...
# 10                          Victorian Hotel Vancouver
# 11         Vancouver Marriott Pinnacle Downtown Hotel
# 12                                   The Sylvia Hotel
# 13                               YWCA Hotel/Residence
# 14                       Metropolitan Hotel Vancouver
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 1   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 2   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 3   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 4   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 5   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 6   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 7   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 8   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 9   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 10  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 11  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 12  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 13  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
# 14  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603598705    False
#
#                     location.address            location.crossStreet  \
# 0                   801 W Georgia St                      at Howe St
# 1                 845 Burrard Street      btwn Smithe St & Robson St
# 2              1128 West Georgia St.                         Thurlow
# 3            900 West Georgia Street           btwn Burrard & Hornby
# 4                      322 Davie St.                 at Hamilton St.
# 5                 1180 West Hastings                 Hastings & Bute
# 6                  567 Hornby Street       btn W Pender and Dunsmuir
# 7                      773 Beatty St  btw Robson St. and Georgia St.
# 8            791 West Georgia Street                             NaN
# 9                  1100 Granville St                 at Helmcken St.
# 10  514 Homer St Vancouver BC Canada                          Pender
# 11         1128 West Hastings Street                             NaN
# 12                   1154 Gilford St                             NaN
# 13                    733 Beatty St.                  Off Robson St.
# 14                   645 Howe Street                             NaN
#
#     location.lat  location.lng  \
# 0      49.283429   -123.118911
# 1      49.282640   -123.123875
# 2      49.285934   -123.124081
# 3      49.283805   -123.120944
# 4      49.274654   -123.122332
# 5      49.288401   -123.122343
# 6      49.285332   -123.118111
# 7      49.278237   -123.113485
# 8      49.283210   -123.118407
# 9      49.277823   -123.124630
# 10     49.282517   -123.112144
# 11     49.287790   -123.120365
# 12     49.288784   -123.142615
# 13     49.278414   -123.112770
# 14     49.284180   -123.118430
#
#                               location.labeledLatLngs location.postalCode  \
# 0   [{'label': 'display', 'lat': 49.28342914255638...             V6C 1P7
# 1   [{'label': 'display', 'lat': 49.28264004904225...             V6Z 2K6
# 2   [{'label': 'display', 'lat': 49.28593423238485...             V6E 0A8
# 3   [{'label': 'display', 'lat': 49.28380548632319...             V6C 2W6
# 4   [{'label': 'display', 'lat': 49.27465442332043...             V6B 5Z6
# 5   [{'label': 'display', 'lat': 49.288401, 'lng':...             V6E 4R5
# 6   [{'label': 'display', 'lat': 49.28533209101862...             V6C 2E8
# 7   [{'label': 'display', 'lat': 49.27823662737742...             V6B 2M4
# 8   [{'label': 'display', 'lat': 49.28321030608094...             V6C 2T4
# 9   [{'label': 'display', 'lat': 49.277823, 'lng':...             V6Z 2B6
# 10  [{'label': 'display', 'lat': 49.28251724902659...                 NaN
# 11  [{'label': 'display', 'lat': 49.28778960562971...             V6E 4R5
# 12  [{'label': 'display', 'lat': 49.288784, 'lng':...             V6G 2P6
# 13  [{'label': 'display', 'lat': 49.27841416220364...             V6B 4P4
# 14  [{'label': 'display', 'lat': 49.2841801, 'lng'...             V6C 2Y9
#
#    location.cc location.city location.state location.country  \
# 0           CA     Vancouver             BC           Canada
# 1           CA     Vancouver             BC           Canada
# 2           CA     Vancouver             BC           Canada
# 3           CA     Vancouver             BC           Canada
# 4           CA     Vancouver             BC           Canada
# 5           CA     Vancouver             BC           Canada
# 6           CA     Vancouver             BC           Canada
# 7           CA     Vancouver             BC           Canada
# 8           CA     Vancouver             BC           Canada
# 9           CA     Vancouver             BC           Canada
# 10          CA     Vancouver             BC           Canada
# 11          CA     Vancouver             BC           Canada
# 12          CA     Vancouver             BC           Canada
# 13          CA     Vancouver             BC           Canada
# 14          CA     Vancouver             BC           Canada
#
#                             location.formattedAddress venuePage.id  \
# 0   [801 W Georgia St (at Howe St), Vancouver BC V...     37012938
# 1   [845 Burrard Street (btwn Smithe St & Robson S...    584836110
# 2   [1128 West Georgia St. (Thurlow), Vancouver BC...          NaN
# 3   [900 West Georgia Street (btwn Burrard & Hornb...          NaN
# 4   [322 Davie St. (at Hamilton St.), Vancouver BC...          NaN
# 5   [1180 West Hastings (Hastings & Bute), Vancouv...    512550599
# 6   [567 Hornby Street (btn W Pender and Dunsmuir)...          NaN
# 7   [773 Beatty St (btw Robson St. and Georgia St....     47719517
# 8   [791 West Georgia Street, Vancouver BC V6C 2T4...          NaN
# 9   [1100 Granville St (at Helmcken St.), Vancouve...     36728873
# 10  [514 Homer St Vancouver BC Canada (Pender), Va...          NaN
# 11  [1128 West Hastings Street, Vancouver BC V6E 4...    129932557
# 12    [1154 Gilford St, Vancouver BC V6G 2P6, Canada]          NaN
# 13  [733 Beatty St. (Off Robson St.), Vancouver BC...     45901530
# 14    [645 Howe Street, Vancouver BC V6C 2Y9, Canada]          NaN
#
#    location.neighborhood
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN

# %% [markdown]
# ## 7. OK! Cleansing time

# %% [markdown]
# ##### Now it's time to clean our data frame and keep just appropriate columns
# ###### We're going to drop all columns that we don't need to boost performance

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'rating'] + [col for col in ljoin_df.columns if col.startswith('location.')] + ['id']
dataframe_filtered = ljoin_df.loc[:, filtered_columns]

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  rating  \
# 0                              Rosewood Hotel Georgia     9.3
# 1                        Sutton Place Hotel Vancouver     8.6
# 2                                    Shangri-La Hotel     8.6
# 3                        The Fairmont Hotel Vancouver     8.5
# 4                                          Opus Hotel     8.4
# 5           Coast Coal Harbour Vancouver Hotel by APA     8.3
# 6                                      Hotel LeSoleil     8.3
# 7                                Georgian Court Hotel     8.2
# 8                        Four Seasons Hotel Vancouver     8.0
# 9   Best Western Plus Chateau Granville Hotel & Su...     7.9
# 10                          Victorian Hotel Vancouver     7.8
# 11         Vancouver Marriott Pinnacle Downtown Hotel     7.5
# 12                                   The Sylvia Hotel     7.5
# 13                               YWCA Hotel/Residence     7.3
# 14                       Metropolitan Hotel Vancouver     7.1
#
#                              address                     crossStreet  \
# 0                   801 W Georgia St                      at Howe St
# 1                 845 Burrard Street      btwn Smithe St & Robson St
# 2              1128 West Georgia St.                         Thurlow
# 3            900 West Georgia Street           btwn Burrard & Hornby
# 4                      322 Davie St.                 at Hamilton St.
# 5                 1180 West Hastings                 Hastings & Bute
# 6                  567 Hornby Street       btn W Pender and Dunsmuir
# 7                      773 Beatty St  btw Robson St. and Georgia St.
# 8            791 West Georgia Street                             NaN
# 9                  1100 Granville St                 at Helmcken St.
# 10  514 Homer St Vancouver BC Canada                          Pender
# 11         1128 West Hastings Street                             NaN
# 12                   1154 Gilford St                             NaN
# 13                    733 Beatty St.                  Off Robson St.
# 14                   645 Howe Street                             NaN
#
#           lat         lng                                     labeledLatLngs  \
# 0   49.283429 -123.118911  [{'label': 'display', 'lat': 49.28342914255638...
# 1   49.282640 -123.123875  [{'label': 'display', 'lat': 49.28264004904225...
# 2   49.285934 -123.124081  [{'label': 'display', 'lat': 49.28593423238485...
# 3   49.283805 -123.120944  [{'label': 'display', 'lat': 49.28380548632319...
# 4   49.274654 -123.122332  [{'label': 'display', 'lat': 49.27465442332043...
# 5   49.288401 -123.122343  [{'label': 'display', 'lat': 49.288401, 'lng':...
# 6   49.285332 -123.118111  [{'label': 'display', 'lat': 49.28533209101862...
# 7   49.278237 -123.113485  [{'label': 'display', 'lat': 49.27823662737742...
# 8   49.283210 -123.118407  [{'label': 'display', 'lat': 49.28321030608094...
# 9   49.277823 -123.124630  [{'label': 'display', 'lat': 49.277823, 'lng':...
# 10  49.282517 -123.112144  [{'label': 'display', 'lat': 49.28251724902659...
# 11  49.287790 -123.120365  [{'label': 'display', 'lat': 49.28778960562971...
# 12  49.288784 -123.142615  [{'label': 'display', 'lat': 49.288784, 'lng':...
# 13  49.278414 -123.112770  [{'label': 'display', 'lat': 49.27841416220364...
# 14  49.284180 -123.118430  [{'label': 'display', 'lat': 49.2841801, 'lng'...
#
#    postalCode  cc       city state country  \
# 0     V6C 1P7  CA  Vancouver    BC  Canada
# 1     V6Z 2K6  CA  Vancouver    BC  Canada
# 2     V6E 0A8  CA  Vancouver    BC  Canada
# 3     V6C 2W6  CA  Vancouver    BC  Canada
# 4     V6B 5Z6  CA  Vancouver    BC  Canada
# 5     V6E 4R5  CA  Vancouver    BC  Canada
# 6     V6C 2E8  CA  Vancouver    BC  Canada
# 7     V6B 2M4  CA  Vancouver    BC  Canada
# 8     V6C 2T4  CA  Vancouver    BC  Canada
# 9     V6Z 2B6  CA  Vancouver    BC  Canada
# 10        NaN  CA  Vancouver    BC  Canada
# 11    V6E 4R5  CA  Vancouver    BC  Canada
# 12    V6G 2P6  CA  Vancouver    BC  Canada
# 13    V6B 4P4  CA  Vancouver    BC  Canada
# 14    V6C 2Y9  CA  Vancouver    BC  Canada
#
#                                      formattedAddress neighborhood  \
# 0   [801 W Georgia St (at Howe St), Vancouver BC V...          NaN
# 1   [845 Burrard Street (btwn Smithe St & Robson S...          NaN
# 2   [1128 West Georgia St. (Thurlow), Vancouver BC...          NaN
# 3   [900 West Georgia Street (btwn Burrard & Hornb...          NaN
# 4   [322 Davie St. (at Hamilton St.), Vancouver BC...          NaN
# 5   [1180 West Hastings (Hastings & Bute), Vancouv...          NaN
# 6   [567 Hornby Street (btn W Pender and Dunsmuir)...          NaN
# 7   [773 Beatty St (btw Robson St. and Georgia St....          NaN
# 8   [791 West Georgia Street, Vancouver BC V6C 2T4...          NaN
# 9   [1100 Granville St (at Helmcken St.), Vancouve...          NaN
# 10  [514 Homer St Vancouver BC Canada (Pender), Va...          NaN
# 11  [1128 West Hastings Street, Vancouver BC V6E 4...          NaN
# 12    [1154 Gilford St, Vancouver BC V6G 2P6, Canada]          NaN
# 13  [733 Beatty St. (Off Robson St.), Vancouver BC...          NaN
# 14    [645 Howe Street, Vancouver BC V6C 2Y9, Canada]          NaN
#
#                           id
# 0   4d5ec8ce29ef236ae0cb9059
# 1   4aa74575f964a5208f4c20e3
# 2   4acd3910f964a5207dcb20e3
# 3   4af0f4e4f964a5204ae021e3
# 4   4aa738def964a520594c20e3
# 5   4ad5f692f964a520350421e3
# 6   4aab548ef964a520725920e3
# 7   4b99e544f964a5201f9635e3
# 8   4abe5a61f964a520ec8c20e3
# 9   4b9b2307f964a5206df535e3
# 10  4bd09a3f1f89ce723bb967ea
# 11  4aab4ce8f964a5205a5920e3
# 12  4bd09a421f89ce723fb967ea
# 13  4af2380af964a520aae621e3
# 14  4aab560af964a520785920e3

# %%
# Get list of column names to more cleansing dataframe
dataframe_filtered.columns
# Out:
# Index(['name', 'rating', 'address', 'crossStreet', 'lat', 'lng',
#        'labeledLatLngs', 'postalCode', 'cc', 'city', 'state', 'country',
#        'formattedAddress', 'neighborhood', 'id'],
#       dtype='object')

# %%
# We just need to keep id, name, address, lat, lng so:
hotel_df = dataframe_filtered.loc[:,['name', 'rating', 'address', 'lat', 'lng','id']]
# our final data frame of hotels is:
hotel_df
# Out:
#                                                  name  rating  \
# 0                              Rosewood Hotel Georgia     9.3
# 1                        Sutton Place Hotel Vancouver     8.6
# 2                                    Shangri-La Hotel     8.6
# 3                        The Fairmont Hotel Vancouver     8.5
# 4                                          Opus Hotel     8.4
# 5           Coast Coal Harbour Vancouver Hotel by APA     8.3
# 6                                      Hotel LeSoleil     8.3
# 7                                Georgian Court Hotel     8.2
# 8                        Four Seasons Hotel Vancouver     8.0
# 9   Best Western Plus Chateau Granville Hotel & Su...     7.9
# 10                          Victorian Hotel Vancouver     7.8
# 11         Vancouver Marriott Pinnacle Downtown Hotel     7.5
# 12                                   The Sylvia Hotel     7.5
# 13                               YWCA Hotel/Residence     7.3
# 14                       Metropolitan Hotel Vancouver     7.1
#
#                              address        lat         lng  \
# 0                   801 W Georgia St  49.283429 -123.118911
# 1                 845 Burrard Street  49.282640 -123.123875
# 2              1128 West Georgia St.  49.285934 -123.124081
# 3            900 West Georgia Street  49.283805 -123.120944
# 4                      322 Davie St.  49.274654 -123.122332
# 5                 1180 West Hastings  49.288401 -123.122343
# 6                  567 Hornby Street  49.285332 -123.118111
# 7                      773 Beatty St  49.278237 -123.113485
# 8            791 West Georgia Street  49.283210 -123.118407
# 9                  1100 Granville St  49.277823 -123.124630
# 10  514 Homer St Vancouver BC Canada  49.282517 -123.112144
# 11         1128 West Hastings Street  49.287790 -123.120365
# 12                   1154 Gilford St  49.288784 -123.142615
# 13                    733 Beatty St.  49.278414 -123.112770
# 14                   645 Howe Street  49.284180 -123.118430
#
#                           id
# 0   4d5ec8ce29ef236ae0cb9059
# 1   4aa74575f964a5208f4c20e3
# 2   4acd3910f964a5207dcb20e3
# 3   4af0f4e4f964a5204ae021e3
# 4   4aa738def964a520594c20e3
# 5   4ad5f692f964a520350421e3
# 6   4aab548ef964a520725920e3
# 7   4b99e544f964a5201f9635e3
# 8   4abe5a61f964a520ec8c20e3
# 9   4b9b2307f964a5206df535e3
# 10  4bd09a3f1f89ce723bb967ea
# 11  4aab4ce8f964a5205a5920e3
# 12  4bd09a421f89ce723fb967ea
# 13  4af2380af964a520aae621e3
# 14  4aab560af964a520785920e3

# %% [markdown]
# #### 8. Now we just need to gently save it as csv for future use

# %%
hotel_df.to_csv('hotel_df.csv', index=False)

# %% [markdown]
# ## Same as what we did untill now, we should repeat this process 4 more time to create our data setd:
# * bus_df.csv
# * metro_df.csv
# * unrban_df.csv
# * rest_df.csv
#
# ###### Note: rest_df stands for restaurant dataframe

# %% [markdown]
# #### So, as soon as we are done with retrieving data, we start to put them on map for best usage experience

# %% [markdown]
# ##### first we need to install and import Folium library so if you already have it just run code below otherwise uncomment first line and then run the block

# %%
# !pip install folium
import folium

# %% [markdown]
# #### Import all csv file that we've already created

# %%
metro_df = pd.read_csv('metro_df.csv')
hotel_df = pd.read_csv('hotel_df.csv')
urban_df = pd.read_csv('urban_df.csv')
rest_df = pd.read_csv('rest_df.csv')
bus_df = pd.read_csv('bus_df.csv')

# %%
hotel_df.columns
# Out:
# Index(['name', 'rating', 'address', 'lat', 'lng', 'id'], dtype='object')

# %% [markdown]
# #### Since we don't need id column anymore we're going to remove it to improve speed of next steps

# %%
metro_df = metro_df.loc[:,['name', 'address', 'lat', 'lng']]
hotel_df = hotel_df.loc[:,['name', 'rating', 'address', 'lat', 'lng']]
urban_df = urban_df.loc[:,['name', 'rating', 'address', 'lat', 'lng']]
rest_df = rest_df.loc[:,['name', 'rating', 'address', 'lat', 'lng']]
bus_df = bus_df.loc[:,['name', 'address', 'lat', 'lng']]

# %% [markdown]
# #### Test our dataframes

# %%
metro_df.head()
# Out:
#                                      name                 address        lat  \
# 0                              Metro news       Oakridge skytrain  49.250795
# 1            King Edward SkyTrain Station  500 W King Edward Ave.  49.249120
# 2                              Metro News          100 W 49th Ave  49.225866
# 3                              Metro News   (@ 16th Ave & Oak St)  49.259135
# 4  Yaletown - Roundhouse SkyTrain Station           200 Davie St.  49.274531
#
#           lng
# 0 -123.117416
# 1 -123.115703
# 2 -123.116441
# 3 -123.127178
# 4 -123.121993

# %%
hotel_df.head()
# Out:
#                            name  rating                  address        lat  \
# 0        Rosewood Hotel Georgia     9.3         801 W Georgia St  49.283429
# 1  Sutton Place Hotel Vancouver     8.6       845 Burrard Street  49.282640
# 2              Shangri-La Hotel     8.6    1128 West Georgia St.  49.285934
# 3  The Fairmont Hotel Vancouver     8.5  900 West Georgia Street  49.283805
# 4                    Opus Hotel     8.4            322 Davie St.  49.274654
#
#           lng
# 0 -123.118911
# 1 -123.123875
# 2 -123.124081
# 3 -123.120944
# 4 -123.122332

# %%
urban_df.head()
# Out:
#                                name  rating              address        lat  \
# 0                      Stanley Park     9.6      Stanley Park Dr  49.302488
# 1  Stanley Park English Bay Seawall     9.6            Beach Ave  49.290230
# 2      Pacific Spirit Regional Park     9.4  Pacific Spirit Park  49.249263
# 3              Queen Elizabeth Park     9.3       4600 Cambie St  49.241565
# 4                    David Lam Park     9.2   1300 Pacific Blvd.  49.272467
#
#           lng
# 0 -123.141718
# 1 -123.146868
# 2 -123.211370
# 3 -123.113355
# 4 -123.123866

# %%
bus_df.head()
# Out:
#                      name               address        lat         lng
# 0     Bus Stop 51512 (25)     W King Edward Ave  49.248431 -123.118522
# 1     Bus Stop 51511 (25)     W King Edward Ave  49.248998 -123.121991
# 2     Bus Stop 51574 (25)  WB W King Edward Ave  49.249126 -123.115789
# 3  Bus Stop 50475 (15,33)             Cambie St  49.249172 -123.115393
# 4  Bus Stop 50419 (15,33)             Cambie St  49.248611 -123.115708

# %%
rest_df.head()
# Out:
#                              name  rating                 address        lat  \
# 0           Hawksworth Restaurant     9.1        801 W Georgia St  49.283362
# 1               España Restaurant     8.6         1118 Denman St.  49.288019
# 2            Cardero's Restaurant     8.5  1583 Coal Harbour Quay  49.291655
# 3        Peaceful Restaurant 和平饭店     8.1            43 E 5th Ave  49.266510
# 4  The Sandbar Seafood Restaurant     8.1       1536 Johnston St.  49.272188
#
#           lng
# 0 -123.119462
# 1 -123.140467
# 2 -123.127686
# 3 -123.103731
# 4 -123.133918

# %% [markdown]
# #### Everything is ok, so we're going to create folium map base on our dataframes

# %%
hotel_df.shape[0]
# Out:
# 15

# %%
## latitude and longitude of Vancouver
latitude = 49.2576508
longitude = -123.10

venues_map = folium.Map(location=[latitude, longitude], zoom_start=12)  # It will create a map around Vancouver city


# add the hotels as red circle markers
for lat, lng, label in zip(hotel_df['lat'], hotel_df['lng'], hotel_df['name']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

    
#add the bus stations as purple circle markers
for lat, lng, label in zip(bus_df['lat'], bus_df['lng'], bus_df['name']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='purple',
        popup=label,
        fill = True,
        fill_color='purple',
        fill_opacity=0.6
    ).add_to(venues_map)
    
#add the metro stations as yellow circle markers
for lat, lng, label in zip(metro_df['lat'], metro_df['lng'], metro_df['name']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_map)
    
#add the restaurants as orange circle markers
for lat, lng, label in zip(rest_df['lat'], rest_df['lng'], rest_df['name']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(venues_map)
    
#add the parks as green circle markers
for lat, lng, label in zip(urban_df['lat'], urban_df['lng'], urban_df['name']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)


# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Maps Description:
#
# ##### __Purpule circles__: *Bus stops*
# ##### __Yellow circles__: *Metro Stations*
# ##### __Red circles__: *Hotels with overall rank of 7 or greater*
# ##### __orange circles__: *Restaurants with overall rank of 7 or greater*
# ##### __Green circles__: *Urban areas(In this case, parks) with overall rank of 7 or greater*

# %% [markdown]
# ##### __Reporter github__:  *https://github.com/spacelover92*
# ##### __Creation Date__: October 25, 2020
